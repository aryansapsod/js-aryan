# %%
#dict

person_1={"name_1":"Aryan","age":"21","city":"Murud"}


person2={"name":"Oma","age":"21","city":"umarga"}
print(person_1)
for key in person_1.keys():
    print(f"{key}={person_1[key]}")
    
print("-"*30)

for key in person2.keys():
    print(f"{key}={person2[key]}")

def can_vote(person):
    if person("age")>18:
        print("Eligible for vote")
    else:
        print("Not eligible for vote")

can_vote(person_1)
# Out:
# {'name_1': 'Aryan', 'age': '21', 'city': 'Murud'}
# name_1=Aryan
# age=21
# city=Murud
# ------------------------------
# name=Oma
# age=21
# city=umarga
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 22
#      19     else:
#      20         print("Not eligible for vote")
# ---> 22 can_vote(person_1)
#
# Cell In[19], line 17, in can_vote(person)
#      16 def can_vote(person):
# ---> 17     if person("age")>18:
#      18         print("Eligible for vote")
#      19     else:
#
# TypeError: 'dict' object is not callable

# %%
def can_vote():
    if person_1("age")>18:
        print("Eligible for vote")
    else:
        print("Not eligible for vote")
can_vote()#
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 6
#       4     else:
#       5         print("Not eligible for vote")
# ----> 6 can_vote()#
#
# Cell In[15], line 2, in can_vote()
#       1 def can_vote():
# ----> 2     if person_1("age")>18:
#       3         print("Eligible for vote")
#       4     else:
#
# TypeError: 'dict' object is not callable

# %%
class Person:
    pass
